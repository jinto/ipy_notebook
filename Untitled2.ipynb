# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 20, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

x1,x2,y1,y2 = plt.axis()
plt.axis((x1,20,-1,1))

plt.plot(x, y_sin)
plt.plot(x, y_cos)
